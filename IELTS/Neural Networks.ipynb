# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Input, Concatenate
from tensorflow.keras.models import Model
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
df = pd.read_csv("ielts_dataset_original.csv")

# %%
work_df = df.iloc[:,[0,1, 2, 8]]

# %%
work_df
# Out:
#       Task_Type                                           Question  \
# 0             1  The bar chart below describes some changes abo...
# 1             2  Rich countries often give money to poorer coun...
# 2             1  The bar chart below describes some changes abo...
# 3             2  Rich countries often give money to poorer coun...
# 4             1  The graph below shows the number of overseas v...
# ...         ...                                                ...
# 1430          2  Without capital punishment our lives are less ...
# 1431          2  Some people think that they can learn better b...
# 1432          2  Nowadays people like to change their day by da...
# 1433          2  Universities should allocate the same amount o...
# 1434          2  Modern medicine helps to live a longer life. D...
#
#                                                   Essay  Overall
# 0     Between 1995 and 2010, a study was conducted r...      5.5
# 1     Poverty represents a worldwide crisis. It is t...      6.5
# 2     The left chart shows the population change hap...      5.0
# 3     Human beings are facing many challenges nowada...      5.5
# 4     Information about the thousands of visits from...      7.0
# ...                                                 ...      ...
# 1430  Serious crimes need capital punishment so that...      5.0
# 1431  It is certainly said that learning is an ongoi...      5.0
# 1432  popular hobbies rather than their individual a...      5.0
# 1433  Yes, I do feel that universities should have a...      5.0
# 1434  The modern medicine is very important for livi...      5.0
#
# [1435 rows x 4 columns]

# %%
work_df['QnA']= work_df.iloc[:,1] + '##' + work_df.iloc[:, 2]
# Out:
# C:\Users\mango\AppData\Local\Temp\ipykernel_19824\2786127801.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   work_df['QnA']= work_df.iloc[:,1] + '##' + work_df.iloc[:, 2]

# %%
#Tokenizing text
tokenizer = Tokenizer()
tokenizer.fit_on_texts(work_df['QnA'])
X_sequences = tokenizer.texts_to_sequences(work_df['QnA'])
X_padded = pad_sequences(X_sequences)

# %%
X_task_type = work_df['Task_Type'].values.reshape(-1, 1)
y = work_df['Overall']

# %%
X_train_text, X_val_text, X_train_task_type, X_val_task_type, y_train, y_val = train_test_split(
    X_padded, X_task_type, y, test_size=0.3, random_state=42)

# %%
text_input = Input(shape=(X_padded.shape[1],))
task_type_input = Input(shape=(1,))
embedding_layer = Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=50, input_length=X_padded.shape[1])(text_input)
lstm_layer = LSTM(128)(embedding_layer)
concatenated = Concatenate()([lstm_layer, task_type_input])
output = Dense(1, activation='linear')(concatenated)

# %%
model = Model(inputs=[text_input, task_type_input], outputs=output)
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.fit([X_train_text, X_train_task_type], y_train, validation_data=([X_val_text, X_val_task_type], y_val), epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 45s 1s/step - loss: 12.8286 - val_loss: 1.0509
# Epoch 2/10
# 32/32 [==============================] - 38s 1s/step - loss: 1.1441 - val_loss: 1.0606
# Epoch 3/10
# 32/32 [==============================] - 38s 1s/step - loss: 1.1137 - val_loss: 1.0297
# Epoch 4/10
# 32/32 [==============================] - 39s 1s/step - loss: 1.0434 - val_loss: 1.0272
# Epoch 5/10
# 32/32 [==============================] - 38s 1s/step - loss: 0.9220 - val_loss: 1.0167
# Epoch 6/10
# 32/32 [==============================] - 37s 1s/step - loss: 0.7226 - val_loss: 1.0380
# Epoch 7/10
# 32/32 [==============================] - 37s 1s/step - loss: 0.5465 - val_loss: 1.0974
# Epoch 8/10
# 32/32 [==============================] - 38s 1s/step - loss: 0.4460 - val_loss: 1.1155
# Epoch 9/10
# 32/32 [==============================] - 37s 1s/step - loss: 0.3796 - val_loss: 1.1229
# Epoch 10/10
# 32/32 [==============================] - 38s 1s/step - loss: 0.3278 - val_loss: 1.1499

# %%
val_loss = model.evaluate([X_val_text, X_val_task_type], y_val)
# Out:
# 14/14 [==============================] - 5s 363ms/step - loss: 1.1499

# %%
y_pred= model.predict([X_val_text, X_val_task_type])
for i in range(len(y_val)):
    print(f"Actual Score: {y_val.iloc[i]}, Predicted Score: {predictions[i][0]}")
# Out:
# 14/14 [==============================] - 5s 367ms/step
# Actual Score: 6.5, Predicted Score: 6.314497470855713
# Actual Score: 7.5, Predicted Score: 6.731588840484619
# Actual Score: 7.0, Predicted Score: 5.950225830078125
# Actual Score: 6.0, Predicted Score: 7.293788909912109
# Actual Score: 5.5, Predicted Score: 7.3820414543151855
# Actual Score: 6.5, Predicted Score: 8.403034210205078
# Actual Score: 6.5, Predicted Score: 6.721617221832275
# Actual Score: 8.0, Predicted Score: 7.422724723815918
# Actual Score: 6.5, Predicted Score: 5.648571014404297
# Actual Score: 6.5, Predicted Score: 6.6747918128967285
# Actual Score: 6.5, Predicted Score: 6.004540920257568
# Actual Score: 5.5, Predicted Score: 7.17612361907959
# Actual Score: 5.5, Predicted Score: 6.4287590980529785
# Actual Score: 7.0, Predicted Score: 6.825746536254883
# Actual Score: 7.0, Predicted Score: 8.077839851379395
# Actual Score: 8.0, Predicted Score: 6.4710869789123535
# Actual Score: 5.0, Predicted Score: 6.927803993225098
# Actual Score: 7.5, Predicted Score: 6.901040077209473
# Actual Score: 7.0, Predicted Score: 6.563958168029785
# Actual Score: 6.5, Predicted Score: 6.486096382141113
# Actual Score: 9.0, Predicted Score: 8.021673202514648
# Actual Score: 6.5, Predicted Score: 7.941751480102539
# Actual Score: 6.0, Predicted Score: 6.315088272094727
# Actual Score: 6.0, Predicted Score: 5.509066104888916
# Actual Score: 5.0, Predicted Score: 5.127684116363525
# Actual Score: 7.0, Predicted Score: 6.486898422241211
# Actual Score: 8.0, Predicted Score: 6.827690124511719
# Actual Score: 6.5, Predicted Score: 7.106515884399414
# Actual Score: 4.5, Predicted Score: 5.647059917449951
# Actual Score: 6.0, Predicted Score: 5.314944744110107
# Actual Score: 7.0, Predicted Score: 6.601900577545166
# Actual Score: 6.0, Predicted Score: 6.790346145629883
# Actual Score: 8.0, Predicted Score: 6.8483967781066895
# Actual Score: 7.5, Predicted Score: 7.410715103149414
# Actual Score: 5.5, Predicted Score: 5.049091815948486
# Actual Score: 7.5, Predicted Score: 7.022953987121582
# Actual Score: 5.5, Predicted Score: 6.42029333114624
# Actual Score: 8.5, Predicted Score: 6.737612724304199
# Actual Score: 5.0, Predicted Score: 7.384568691253662
# Actual Score: 6.5, Predicted Score: 8.033037185668945
# Actual Score: 8.0, Predicted Score: 6.056036472320557
# Actual Score: 6.0, Predicted Score: 5.60545539855957
# Actual Score: 6.0, Predicted Score: 6.298396587371826
# Actual Score: 6.5, Predicted Score: 6.497711658477783
# Actual Score: 7.0, Predicted Score: 6.364330291748047
# Actual Score: 5.0, Predicted Score: 5.120338439941406
# Actual Score: 5.5, Predicted Score: 7.431140899658203
# Actual Score: 5.5, Predicted Score: 6.607758522033691
# Actual Score: 7.5, Predicted Score: 6.222985744476318
# Actual Score: 5.5, Predicted Score: 6.304646015167236
# Actual Score: 7.0, Predicted Score: 6.302694320678711
# Actual Score: 5.5, Predicted Score: 6.027951717376709
# Actual Score: 5.0, Predicted Score: 5.306495666503906
# Actual Score: 7.0, Predicted Score: 6.268791198730469
# Actual Score: 5.5, Predicted Score: 7.3820414543151855
# Actual Score: 6.0, Predicted Score: 8.313605308532715
# Actual Score: 6.0, Predicted Score: 6.657896518707275
# Actual Score: 6.5, Predicted Score: 7.195215702056885
# Actual Score: 7.0, Predicted Score: 7.441664218902588
# Actual Score: 7.5, Predicted Score: 6.939200401306152
# Actual Score: 6.5, Predicted Score: 7.777884006500244
# Actual Score: 8.0, Predicted Score: 8.06907844543457
# Actual Score: 6.5, Predicted Score: 5.986606121063232
# Actual Score: 6.0, Predicted Score: 5.450856685638428
# Actual Score: 8.0, Predicted Score: 7.1739983558654785
# Actual Score: 5.5, Predicted Score: 6.602032661437988
# Actual Score: 5.5, Predicted Score: 6.393608570098877
# Actual Score: 5.5, Predicted Score: 5.382853031158447
# Actual Score: 6.5, Predicted Score: 7.412015914916992
# Actual Score: 4.0, Predicted Score: 6.631953716278076
# Actual Score: 5.5, Predicted Score: 7.199491500854492
# Actual Score: 8.0, Predicted Score: 7.337891578674316
# Actual Score: 8.0, Predicted Score: 6.617348670959473
# Actual Score: 6.5, Predicted Score: 5.184544086456299
# Actual Score: 7.0, Predicted Score: 7.697447776794434
# Actual Score: 7.0, Predicted Score: 5.487455368041992
# Actual Score: 5.0, Predicted Score: 7.28410530090332
# Actual Score: 6.5, Predicted Score: 6.358993053436279
# Actual Score: 6.0, Predicted Score: 6.149016857147217
# Actual Score: 8.5, Predicted Score: 7.207639217376709
# Actual Score: 6.0, Predicted Score: 6.453023910522461
# Actual Score: 6.5, Predicted Score: 6.570353031158447
# Actual Score: 7.0, Predicted Score: 6.924262046813965
# Actual Score: 5.5, Predicted Score: 5.694188117980957
# Actual Score: 5.0, Predicted Score: 5.951224327087402
# Actual Score: 6.0, Predicted Score: 6.368197917938232
# Actual Score: 5.5, Predicted Score: 6.671350955963135
# Actual Score: 6.0, Predicted Score: 6.592672348022461
# Actual Score: 7.0, Predicted Score: 7.680171012878418
# Actual Score: 6.5, Predicted Score: 7.134086608886719
# Actual Score: 5.5, Predicted Score: 5.41257905960083
# Actual Score: 6.5, Predicted Score: 6.055815696716309
# Actual Score: 6.5, Predicted Score: 6.191496849060059
# Actual Score: 8.0, Predicted Score: 7.337891578674316
# Actual Score: 6.5, Predicted Score: 6.515353679656982
# Actual Score: 7.0, Predicted Score: 5.919539928436279
# Actual Score: 5.0, Predicted Score: 6.617016792297363

# %%
mae = mean_absolute_error(y_val, y_pred)
rmse = mean_squared_error(y_val, y_pred, squared=False)

# %%
print(mae)
# Out:
# 0.8236106553929587

# %%
print(rmse)
# Out:
# 1.0723565156121684
